# %% [markdown]
# # SINDy-SHRED: Synthetic Data Example
#
# This notebook demonstrates SINDy-SHRED on a synthetic toy dataset using the `SINDySHRED` class. The class handles data preprocessing, model training, and post-hoc SINDy discovery automatically.
#
# ## Overview
#
# **SHRED** (SHallow REcurrent Decoder) models combine a recurrent layer (GRU) with a shallow decoder network to reconstruct high-dimensional spatio-temporal fields from sensor measurements.
#
# **SINDy-SHRED** extends this by integrating Sparse Identification of Nonlinear Dynamics (SINDy) to learn interpretable governing equations:
#
# $$\dot{z} = \Theta(z) \xi$$
#
# ## Synthetic Data
#
# The synthetic data uses the **FitzHugh-Nagumo Model** with spatially delayed copies:
#
# $$\dot{v} = v - \frac{1}{3}v^3 - w + I_{ext}$$
# $$\dot{w} = \frac{1}{\tau}(v + a - bw)$$
#
# ## Notebook Structure
#
# 1. Setup and Imports
# 2. Data Generation
# 3. Model Configuration and Training
# 4. SINDy Discovery
# 5. Evaluation
# 6. Save Results

# %% [markdown]
# ## 1. Setup and Imports

# %%
import copy
import os
import random
import warnings

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import torch
from scipy.integrate import solve_ivp

import plotting

# Local modules
from sindy_shred import SINDySHRED

warnings.filterwarnings("ignore")

# Create results directory
RESULTS_DIR = "results/synthetic_data"
os.makedirs(RESULTS_DIR, exist_ok=True)
print(f"Results will be saved to: {RESULTS_DIR}")
# Out:
# Results will be saved to: results/synthetic_data

# %% [markdown]
# ### Device and Seed Configuration

# %%
# Device selection
if torch.backends.mps.is_available():
    device = "mps"
elif torch.cuda.is_available():
    device = "cuda"
else:
    device = "cpu"

print(f"Using device: {device}")

# Set seeds for reproducibility
SEED = 0
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if device == "cuda":
    torch.cuda.manual_seed(SEED)
# Out:
# Using device: mps

# %% [markdown]
# ### Plotting Configuration

# %%
sns.set_context("paper")
sns.set_style("whitegrid")

pcolor_kwargs = {
    "vmin": -3,
    "vmax": 3,
    "cmap": "RdBu_r",
    "rasterized": True,
}

# %% [markdown]
# ## 2. Data Generation
#
# Generate synthetic spatio-temporal data from the FitzHugh-Nagumo model with spatially delayed copies.

# %% [markdown]
# ### Define Dynamical System

# %%
# def rhs_FNM(t, x, tau, a, b, Iext):
#     """FitzHugh-Nagumo Model.

#     Parameters
#     ----------
#     t : float
#         Time (unused, for ODE solver interface).
#     x : array-like
#         State vector [v, w].
#     tau : float
#         Time constant.
#     a, b : float
#         Model parameters.
#     Iext : float
#         External input current.

#     Returns
#     -------
#     dx : array-like
#         Time derivatives [dv/dt, dw/dt].
#     """
#     v, w = x
#     vdot = v - (v**3) / 3 - w + Iext
#     wdot = (1 / tau) * (v + a - b * w)
#     return np.array([vdot, wdot])

# %%
# # Time integration parameters
# T = 64
# dt_solve = 0.0001 * 8
# t_solution = np.arange(0, T, dt_solve)

# # FitzHugh-Nagumo parameters
# x0 = np.array([-1.110, -0.125])
# tau1 = 2
# a = 0.7
# b = 0.8
# Iext = 0.65

# # Solve the ODE
# solution_fn = solve_ivp(rhs_FNM, [0, T], x0, t_eval=t_solution, args=(tau1, a, b, Iext))

# print(f"FitzHugh-Nagumo solution shape: {solution_fn.y.shape}")
# Out:
# FitzHugh-Nagumo solution shape: (2, 80000)

# %% [markdown]
# ### Generate Data

# %%
def rhs_vdp(t, z, tau, mu):
    s, u = z

    ds = u
    # du = (1 / tau) * (-2 * eta * u - s - epsilon * s**3)
    du = (1 / tau) * (mu * (1 - s**2) * u - s)
    return np.array([ds, du])

# %%
# Time integration parameters
T = 70
dt_solve = 0.0001
t_solution = np.arange(0, T, dt_solve)

# FitzHugh-Nagumo parameters
# x0 = np.array([0, 2])
x0 = np.array([-1, 1])
tau = 3
mu = 2

# Solve the ODE
solution_vdp = solve_ivp(rhs_vdp, [0, T], x0, t_eval=t_solution, args=(tau, mu))


print(f"Van der Pol solution shape: {solution_vdp.y.shape}")

# Create spatially delayed copies
num_space_dims = 40
delays = np.linspace(0, 0.01, num_space_dims)  # delays in time units
# uv_spatial = np.zeros((len(t_solution), 2 * num_space_dims))

s_spatial = np.zeros((len(t_solution), num_space_dims))

s_obs = solution_vdp.y[0, :]  # Extract position observations

# for i in range(num_space_dims):
#     delay_steps = int(delays[i] / dt_solve)
#     if delay_steps == 0:
#         uv_spatial[:, 2 * i : 2 * i + 2] = solution_vdp.y.T
#     else:
#         # Pad with initial condition and shift
#         uv_spatial[:, 2 * i : 2 * i + 2] = np.vstack(
#             [np.tile(x0, (delay_steps, 1)), solution_vdp.y.T[:-delay_steps, :]]
#         )

for i in range(num_space_dims):
    delay_steps = int(delays[i] / dt_solve)
    if delay_steps == 0:
        s_spatial[:, i] = s_obs
    else:
        # Pad with initial condition and shift
        s_spatial[:, i] = np.concatenate([
            np.full(delay_steps, x0[0]),  # Use initial position
            s_obs[:-delay_steps]
        ])

# Subsample for computational efficiency
substep = 50 * 8
s_spatial = s_spatial[0::substep, :]
# uv_spatial = uv_spatial[0::substep, :]
t_solution = t_solution[0::substep]

# Chop off the first part of the solution when the system is non-stationary.
t_solution = t_solution[150:]
s_spatial = s_spatial[150:, :]
# uv_spatial = uv_spatial[150:, :]


time = t_solution
dt_data = time[1] - time[0]

# Get dimensions
n_space_dims = s_spatial.shape[1]
n_time = s_spatial.shape[0]

# n_space_dims = uv_spatial.shape[1]
# n_time = uv_spatial.shape[0]

# Final data matrix (space x time for visualization)
# data_original = uv_spatial.T
data_original = s_spatial.T
space_dim = np.arange(n_space_dims)

print(f"Data shape (space x time): {data_original.shape}")
print(f"Time step: {dt_data:.6f}")
print(f"Number of time samples: {n_time}")
print(f"Spatial dimension: {n_space_dims}")
# Out:
# Van der Pol solution shape: (2, 700000)
# Data shape (space x time): (40, 1600)
# Time step: 0.040000
# Number of time samples: 1600
# Spatial dimension: 40

# %% [markdown]
# ### Visualize Generated Data

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 3))

ax.pcolormesh(time, space_dim, data_original, **pcolor_kwargs)
ax.set_title(r"Spatio-temporal data $\mathbf{x}$", loc="left")
ax.set_ylabel("Space")
ax.set_xlabel("Time")

fig.tight_layout()

# Save the data visualization plot
# fig.savefig(f"{RESULTS_DIR}/data_original.pdf", bbox_inches="tight", dpi=300)
# fig.savefig(f"{RESULTS_DIR}/data_original.png", bbox_inches="tight", dpi=300)
# print(f"Saved data plot to {RESULTS_DIR}/data_original.pdf")

plt.show()

# %% [markdown]
# ## 3. Model Configuration and Training
#
# Configure the SINDy-SHRED model using the `SINDySHRED` class.

# %% [markdown]
# ### Data Configuration

# %%
# Sensor configuration (fixed for reproducibility)
sensor_locations = np.array([5, 14, 7])
num_sensors = len(sensor_locations)

# Model hyperparameters
latent_dim = 1
poly_order = 2

# Data split configuration
lags = 120
train_length = 750 // 4
validate_length = 0

# Prepare data (transpose to time x space, subsample)
load_X = copy.deepcopy(data_original)
load_X = load_X.T[::4]  # Subsample
dt = dt_data * 4
lags = lags // 4
t_plot = time[::4]

# SINDy threshold
threshold = 0.0

print(f"Data shape after preprocessing: {load_X.shape}")
print(f"Number of sensors: {num_sensors}")
print(f"Latent dimension: {latent_dim}")
print(f"Trajectory length (lags): {lags}")
print(f"Training length: {train_length}")
print(f"Time step: {dt:.6f}")
# Out:
# Data shape after preprocessing: (400, 40)
# Number of sensors: 3
# Latent dimension: 1
# Trajectory length (lags): 30
# Training length: 187
# Time step: 0.160000

# %%
# Visualize sensor time series
fig, ax = plt.subplots(figsize=(10, 4))
ax.plot(t_plot, load_X[:, sensor_locations], color="b", alpha=0.7)
ax.axvline(t_plot[train_length], color="k", linestyle="--", label="Train/Test split")
ax.axvline(t_plot[lags], color="r", linestyle=":", label="Lag window")
ax.set_xlabel("Time")
ax.set_ylabel("Sensor value")
ax.set_title("Sensor Time Series")
ax.legend()
plt.show()

# %% [markdown]
# ### Initialize and Train Model
#
# The `SINDySHRED` class handles data preprocessing and model training.

# %%
# Initialize the model
model = SINDySHRED(
    latent_dim=latent_dim,
    poly_order=poly_order,
    ode_order=2,  # 1st order ODE: z' = f(z), 2nd order ODE:
    num_epochs=600,
    verbose=True,
    device=device,
    threshold=threshold,
)

# Fit the model
model.fit(
    num_sensors, dt, load_X, lags, train_length, validate_length, sensor_locations
)
# Out:
# 1 : tensor(0.3611, device='mps:0', grad_fn=<AddBackward0>)
# 2 : tensor(0.2490, device='mps:0', grad_fn=<AddBackward0>)
# 3 : tensor(0.2804, device='mps:0', grad_fn=<AddBackward0>)
# 4 : tensor(0.2794, device='mps:0', grad_fn=<AddBackward0>)
# 5 : tensor(0.2469, device='mps:0', grad_fn=<AddBackward0>)
# 6 : tensor(0.2362, device='mps:0', grad_fn=<AddBackward0>)
# 7 : tensor(0.2335, device='mps:0', grad_fn=<AddBackward0>)
# 8 : tensor(0.2280, device='mps:0', grad_fn=<AddBackward0>)
# 9 : tensor(0.2194, device='mps:0', grad_fn=<AddBackward0>)
# 10 : tensor(0.2240, device='mps:0', grad_fn=<AddBackward0>)
# 11 : tensor(0.2281, device='mps:0', grad_fn=<AddBackward0>)
# 12 : tensor(0.2305, device='mps:0', grad_fn=<AddBackward0>)
# 13 : tensor(0.2228, device='mps:0', grad_fn=<AddBackward0>)
# 14 : tensor(0.2211, device='mps:0', grad_fn=<AddBackward0>)
# 15 : tensor(0.2195, device='mps:0', grad_fn=<AddBackward0>)
# 16 : tensor(0.2112, device='mps:0', grad_fn=<AddBackward0>)
# 17 : tensor(0.2117, device='mps:0', grad_fn=<AddBackward0>)
# 18 : tensor(0.2149, device='mps:0', grad_fn=<AddBackward0>)
# 19 : tensor(0.2138, device='mps:0', grad_fn=<AddBackward0>)
# 20 : tensor(0.2134, device='mps:0', grad_fn=<AddBackward0>)
# 21 : tensor(0.2043, device='mps:0', grad_fn=<AddBackward0>)
# 22 : tensor(0.2021, device='mps:0', grad_fn=<AddBackward0>)
# 23 : tensor(0.1973, device='mps:0', grad_fn=<AddBackward0>)
# 24 : tensor(0.1925, device='mps:0', grad_fn=<AddBackward0>)
# 25 : tensor(0.1883, device='mps:0', grad_fn=<AddBackward0>)
# 26 : tensor(0.1907, device='mps:0', grad_fn=<AddBackward0>)
# 27 : tensor(0.1793, device='mps:0', grad_fn=<AddBackward0>)
# 28 : tensor(0.1758, device='mps:0', grad_fn=<AddBackward0>)
# 29 : tensor(0.1663, device='mps:0', grad_fn=<AddBackward0>)
# 30 : tensor(0.1633, device='mps:0', grad_fn=<AddBackward0>)
# 31 : tensor(0.1617, device='mps:0', grad_fn=<AddBackward0>)
# 32 : tensor(0.1497, device='mps:0', grad_fn=<AddBackward0>)
# 33 : tensor(0.1444, device='mps:0', grad_fn=<AddBackward0>)
# 34 : tensor(0.1306, device='mps:0', grad_fn=<AddBackward0>)
# 35 : tensor(0.1253, device='mps:0', grad_fn=<AddBackward0>)
# 36 : tensor(0.1203, device='mps:0', grad_fn=<AddBackward0>)
# 37 : tensor(0.1110, device='mps:0', grad_fn=<AddBackward0>)
# 38 : tensor(0.1010, device='mps:0', grad_fn=<AddBackward0>)
# 39 : tensor(0.0969, device='mps:0', grad_fn=<AddBackward0>)
# 40 : tensor(0.0883, device='mps:0', grad_fn=<AddBackward0>)
# 41 : tensor(0.0883, device='mps:0', grad_fn=<AddBackward0>)
# 42 : tensor(0.0811, device='mps:0', grad_fn=<AddBackward0>)
# 43 : tensor(0.0769, device='mps:0', grad_fn=<AddBackward0>)
# 44 : tensor(0.0756, device='mps:0', grad_fn=<AddBackward0>)
# 45 : tensor(0.0764, device='mps:0', grad_fn=<AddBackward0>)
# 46 : tensor(0.0762, device='mps:0', grad_fn=<AddBackward0>)
# 47 : tensor(0.0745, device='mps:0', grad_fn=<AddBackward0>)
# 48 : tensor(0.0760, device='mps:0', grad_fn=<AddBackward0>)
# 49 : tensor(0.0752, device='mps:0', grad_fn=<AddBackward0>)
# 50 : tensor(0.0784, device='mps:0', grad_fn=<AddBackward0>)
# 51 : tensor(0.0745, device='mps:0', grad_fn=<AddBackward0>)
# 52 : tensor(0.0746, device='mps:0', grad_fn=<AddBackward0>)
# 53 : tensor(0.0762, device='mps:0', grad_fn=<AddBackward0>)
# 54 : tensor(0.0735, device='mps:0', grad_fn=<AddBackward0>)
# 55 : tensor(0.0761, device='mps:0', grad_fn=<AddBackward0>)
# 56 : tensor(0.0730, device='mps:0', grad_fn=<AddBackward0>)
# 57 : tensor(0.0750, device='mps:0', grad_fn=<AddBackward0>)
# 58 : tensor(0.0714, device='mps:0', grad_fn=<AddBackward0>)
# 59 : tensor(0.0751, device='mps:0', grad_fn=<AddBackward0>)
# 60 : tensor(0.0727, device='mps:0', grad_fn=<AddBackward0>)
# 61 : tensor(0.0715, device='mps:0', grad_fn=<AddBackward0>)
# 62 : tensor(0.0711, device='mps:0', grad_fn=<AddBackward0>)
# 63 : tensor(0.0711, device='mps:0', grad_fn=<AddBackward0>)
# 64 : tensor(0.0713, device='mps:0', grad_fn=<AddBackward0>)
# 65 : tensor(0.0727, device='mps:0', grad_fn=<AddBackward0>)
# 66 : tensor(0.0717, device='mps:0', grad_fn=<AddBackward0>)
# 67 : tensor(0.0706, device='mps:0', grad_fn=<AddBackward0>)
# 68 : tensor(0.0724, device='mps:0', grad_fn=<AddBackward0>)
# 69 : tensor(0.0703, device='mps:0', grad_fn=<AddBackward0>)
# 70 : tensor(0.0696, device='mps:0', grad_fn=<AddBackward0>)
# 71 : tensor(0.0715, device='mps:0', grad_fn=<AddBackward0>)
# 72 : tensor(0.0697, device='mps:0', grad_fn=<AddBackward0>)
# 73 : tensor(0.0695, device='mps:0', grad_fn=<AddBackward0>)
# 74 : tensor(0.0700, device='mps:0', grad_fn=<AddBackward0>)
# 75 : tensor(0.0691, device='mps:0', grad_fn=<AddBackward0>)
# 76 : tensor(0.0688, device='mps:0', grad_fn=<AddBackward0>)
# 77 : tensor(0.0691, device='mps:0', grad_fn=<AddBackward0>)
# 78 : tensor(0.0692, device='mps:0', grad_fn=<AddBackward0>)
# 79 : tensor(0.0677, device='mps:0', grad_fn=<AddBackward0>)
# 80 : tensor(0.0667, device='mps:0', grad_fn=<AddBackward0>)
# 81 : tensor(0.0671, device='mps:0', grad_fn=<AddBackward0>)
# 82 : tensor(0.0683, device='mps:0', grad_fn=<AddBackward0>)
# 83 : tensor(0.0659, device='mps:0', grad_fn=<AddBackward0>)
# 84 : tensor(0.0667, device='mps:0', grad_fn=<AddBackward0>)
# 85 : tensor(0.0667, device='mps:0', grad_fn=<AddBackward0>)
# 86 : tensor(0.0661, device='mps:0', grad_fn=<AddBackward0>)
# 87 : tensor(0.0656, device='mps:0', grad_fn=<AddBackward0>)
# 88 : tensor(0.0671, device='mps:0', grad_fn=<AddBackward0>)
# 89 : tensor(0.0660, device='mps:0', grad_fn=<AddBackward0>)
# 90 : tensor(0.0652, device='mps:0', grad_fn=<AddBackward0>)
# 91 : tensor(0.0661, device='mps:0', grad_fn=<AddBackward0>)
# 92 : tensor(0.0665, device='mps:0', grad_fn=<AddBackward0>)
# 93 : tensor(0.0647, device='mps:0', grad_fn=<AddBackward0>)
# 94 : tensor(0.0645, device='mps:0', grad_fn=<AddBackward0>)
# 95 : tensor(0.0656, device='mps:0', grad_fn=<AddBackward0>)
# 96 : tensor(0.0648, device='mps:0', grad_fn=<AddBackward0>)
# 97 : tensor(0.0645, device='mps:0', grad_fn=<AddBackward0>)
# 98 : tensor(0.0640, device='mps:0', grad_fn=<AddBackward0>)
# 99 : tensor(0.0637, device='mps:0', grad_fn=<AddBackward0>)
# 100 : tensor(0.0637, device='mps:0', grad_fn=<AddBackward0>)
# Training epoch 100
# Error tensor(nan, device='mps:0')
# 101 : tensor(0.0629, device='mps:0', grad_fn=<AddBackward0>)
# 102 : tensor(0.0625, device='mps:0', grad_fn=<AddBackward0>)
# 103 : tensor(0.0630, device='mps:0', grad_fn=<AddBackward0>)
# 104 : tensor(0.0630, device='mps:0', grad_fn=<AddBackward0>)
# 105 : tensor(0.0626, device='mps:0', grad_fn=<AddBackward0>)
# 106 : tensor(0.0636, device='mps:0', grad_fn=<AddBackward0>)
# 107 : tensor(0.0634, device='mps:0', grad_fn=<AddBackward0>)
# 108 : tensor(0.0618, device='mps:0', grad_fn=<AddBackward0>)
# 109 : tensor(0.0612, device='mps:0', grad_fn=<AddBackward0>)
# 110 : tensor(0.0625, device='mps:0', grad_fn=<AddBackward0>)
# 111 : tensor(0.0609, device='mps:0', grad_fn=<AddBackward0>)
# 112 : tensor(0.0600, device='mps:0', grad_fn=<AddBackward0>)
# 113 : tensor(0.0610, device='mps:0', grad_fn=<AddBackward0>)
# 114 : tensor(0.0596, device='mps:0', grad_fn=<AddBackward0>)
# 115 : tensor(0.0605, device='mps:0', grad_fn=<AddBackward0>)
# 116 : tensor(0.0591, device='mps:0', grad_fn=<AddBackward0>)
# 117 : tensor(0.0589, device='mps:0', grad_fn=<AddBackward0>)
# 118 : tensor(0.0578, device='mps:0', grad_fn=<AddBackward0>)
# 119 : tensor(0.0576, device='mps:0', grad_fn=<AddBackward0>)
# 120 : tensor(0.0585, device='mps:0', grad_fn=<AddBackward0>)
# 121 : tensor(0.0584, device='mps:0', grad_fn=<AddBackward0>)
# 122 : tensor(0.0576, device='mps:0', grad_fn=<AddBackward0>)
# 123 : tensor(0.0584, device='mps:0', grad_fn=<AddBackward0>)
# 124 : tensor(0.0563, device='mps:0', grad_fn=<AddBackward0>)
# 125 : tensor(0.0563, device='mps:0', grad_fn=<AddBackward0>)
# 126 : tensor(0.0564, device='mps:0', grad_fn=<AddBackward0>)
# 127 : tensor(0.0563, device='mps:0', grad_fn=<AddBackward0>)
# 128 : tensor(0.0562, device='mps:0', grad_fn=<AddBackward0>)
# 129 : tensor(0.0559, device='mps:0', grad_fn=<AddBackward0>)
# 130 : tensor(0.0564, device='mps:0', grad_fn=<AddBackward0>)
# 131 : tensor(0.0545, device='mps:0', grad_fn=<AddBackward0>)
# 132 : tensor(0.0544, device='mps:0', grad_fn=<AddBackward0>)
# 133 : tensor(0.0538, device='mps:0', grad_fn=<AddBackward0>)
# 134 : tensor(0.0533, device='mps:0', grad_fn=<AddBackward0>)
# 135 : tensor(0.0544, device='mps:0', grad_fn=<AddBackward0>)
# 136 : tensor(0.0538, device='mps:0', grad_fn=<AddBackward0>)
# 137 : tensor(0.0527, device='mps:0', grad_fn=<AddBackward0>)
# 138 : tensor(0.0524, device='mps:0', grad_fn=<AddBackward0>)
# 139 : tensor(0.0535, device='mps:0', grad_fn=<AddBackward0>)
# 140 : tensor(0.0513, device='mps:0', grad_fn=<AddBackward0>)
# 141 : tensor(0.0510, device='mps:0', grad_fn=<AddBackward0>)
# 142 : tensor(0.0514, device='mps:0', grad_fn=<AddBackward0>)
# 143 : tensor(0.0515, device='mps:0', grad_fn=<AddBackward0>)
# 144 : tensor(0.0510, device='mps:0', grad_fn=<AddBackward0>)
# 145 : tensor(0.0492, device='mps:0', grad_fn=<AddBackward0>)
# 146 : tensor(0.0496, device='mps:0', grad_fn=<AddBackward0>)
# 147 : tensor(0.0483, device='mps:0', grad_fn=<AddBackward0>)
# 148 : tensor(0.0491, device='mps:0', grad_fn=<AddBackward0>)
# 149 : tensor(0.0491, device='mps:0', grad_fn=<AddBackward0>)
# 150 : tensor(0.0481, device='mps:0', grad_fn=<AddBackward0>)
# 151 : tensor(0.0487, device='mps:0', grad_fn=<AddBackward0>)
# 152 : tensor(0.0474, device='mps:0', grad_fn=<AddBackward0>)
# 153 : tensor(0.0459, device='mps:0', grad_fn=<AddBackward0>)
# 154 : tensor(0.0467, device='mps:0', grad_fn=<AddBackward0>)
# 155 : tensor(0.0462, device='mps:0', grad_fn=<AddBackward0>)
# 156 : tensor(0.0463, device='mps:0', grad_fn=<AddBackward0>)
# 157 : tensor(0.0453, device='mps:0', grad_fn=<AddBackward0>)
# 158 : tensor(0.0444, device='mps:0', grad_fn=<AddBackward0>)
# 159 : tensor(0.0445, device='mps:0', grad_fn=<AddBackward0>)
# 160 : tensor(0.0433, device='mps:0', grad_fn=<AddBackward0>)
# 161 : tensor(0.0430, device='mps:0', grad_fn=<AddBackward0>)
# 162 : tensor(0.0426, device='mps:0', grad_fn=<AddBackward0>)
# 163 : tensor(0.0424, device='mps:0', grad_fn=<AddBackward0>)
# 164 : tensor(0.0416, device='mps:0', grad_fn=<AddBackward0>)
# 165 : tensor(0.0409, device='mps:0', grad_fn=<AddBackward0>)
# 166 : tensor(0.0403, device='mps:0', grad_fn=<AddBackward0>)
# 167 : tensor(0.0409, device='mps:0', grad_fn=<AddBackward0>)
# 168 : tensor(0.0407, device='mps:0', grad_fn=<AddBackward0>)
# 169 : tensor(0.0402, device='mps:0', grad_fn=<AddBackward0>)
# 170 : tensor(0.0394, device='mps:0', grad_fn=<AddBackward0>)
# 171 : tensor(0.0382, device='mps:0', grad_fn=<AddBackward0>)
# 172 : tensor(0.0369, device='mps:0', grad_fn=<AddBackward0>)
# 173 : tensor(0.0376, device='mps:0', grad_fn=<AddBackward0>)
# 174 : tensor(0.0366, device='mps:0', grad_fn=<AddBackward0>)
# 175 : tensor(0.0361, device='mps:0', grad_fn=<AddBackward0>)
# 176 : tensor(0.0360, device='mps:0', grad_fn=<AddBackward0>)
# 177 : tensor(0.0361, device='mps:0', grad_fn=<AddBackward0>)
# 178 : tensor(0.0351, device='mps:0', grad_fn=<AddBackward0>)
# 179 : tensor(0.0349, device='mps:0', grad_fn=<AddBackward0>)
# 180 : tensor(0.0341, device='mps:0', grad_fn=<AddBackward0>)
# 181 : tensor(0.0336, device='mps:0', grad_fn=<AddBackward0>)
# 182 : tensor(0.0337, device='mps:0', grad_fn=<AddBackward0>)
# 183 : tensor(0.0318, device='mps:0', grad_fn=<AddBackward0>)
# 184 : tensor(0.0323, device='mps:0', grad_fn=<AddBackward0>)
# 185 : tensor(0.0321, device='mps:0', grad_fn=<AddBackward0>)
# 186 : tensor(0.0308, device='mps:0', grad_fn=<AddBackward0>)
# 187 : tensor(0.0292, device='mps:0', grad_fn=<AddBackward0>)
# 188 : tensor(0.0299, device='mps:0', grad_fn=<AddBackward0>)
# 189 : tensor(0.0286, device='mps:0', grad_fn=<AddBackward0>)
# 190 : tensor(0.0291, device='mps:0', grad_fn=<AddBackward0>)
# 191 : tensor(0.0286, device='mps:0', grad_fn=<AddBackward0>)
# 192 : tensor(0.0282, device='mps:0', grad_fn=<AddBackward0>)
# 193 : tensor(0.0261, device='mps:0', grad_fn=<AddBackward0>)
# 194 : tensor(0.0266, device='mps:0', grad_fn=<AddBackward0>)
# 195 : tensor(0.0263, device='mps:0', grad_fn=<AddBackward0>)
# 196 : tensor(0.0253, device='mps:0', grad_fn=<AddBackward0>)
# 197 : tensor(0.0257, device='mps:0', grad_fn=<AddBackward0>)
# 198 : tensor(0.0256, device='mps:0', grad_fn=<AddBackward0>)
# 199 : tensor(0.0233, device='mps:0', grad_fn=<AddBackward0>)
# 200 : tensor(0.0228, device='mps:0', grad_fn=<AddBackward0>)
# Training epoch 200
# Error tensor(nan, device='mps:0')
# 201 : tensor(0.0216, device='mps:0', grad_fn=<AddBackward0>)
# 202 : tensor(0.0214, device='mps:0', grad_fn=<AddBackward0>)
# 203 : tensor(0.0199, device='mps:0', grad_fn=<AddBackward0>)
# 204 : tensor(0.0220, device='mps:0', grad_fn=<AddBackward0>)
# 205 : tensor(0.0204, device='mps:0', grad_fn=<AddBackward0>)
# 206 : tensor(0.0210, device='mps:0', grad_fn=<AddBackward0>)
# 207 : tensor(0.0192, device='mps:0', grad_fn=<AddBackward0>)
# 208 : tensor(0.0195, device='mps:0', grad_fn=<AddBackward0>)
# 209 : tensor(0.0176, device='mps:0', grad_fn=<AddBackward0>)
# 210 : tensor(0.0179, device='mps:0', grad_fn=<AddBackward0>)
# 211 : tensor(0.0169, device='mps:0', grad_fn=<AddBackward0>)
# 212 : tensor(0.0183, device='mps:0', grad_fn=<AddBackward0>)
# 213 : tensor(0.0152, device='mps:0', grad_fn=<AddBackward0>)
# 214 : tensor(0.0153, device='mps:0', grad_fn=<AddBackward0>)
# 215 : tensor(0.0151, device='mps:0', grad_fn=<AddBackward0>)
# 216 : tensor(0.0135, device='mps:0', grad_fn=<AddBackward0>)
# 217 : tensor(0.0146, device='mps:0', grad_fn=<AddBackward0>)
# 218 : tensor(0.0139, device='mps:0', grad_fn=<AddBackward0>)
# 219 : tensor(0.0121, device='mps:0', grad_fn=<AddBackward0>)
# 220 : tensor(0.0106, device='mps:0', grad_fn=<AddBackward0>)
# 221 : tensor(0.0126, device='mps:0', grad_fn=<AddBackward0>)
# 222 : tensor(0.0112, device='mps:0', grad_fn=<AddBackward0>)
# 223 : tensor(0.0100, device='mps:0', grad_fn=<AddBackward0>)
# 224 : tensor(0.0086, device='mps:0', grad_fn=<AddBackward0>)
# 225 : tensor(0.0115, device='mps:0', grad_fn=<AddBackward0>)
# 226 : tensor(0.0092, device='mps:0', grad_fn=<AddBackward0>)
# 227 : tensor(0.0084, device='mps:0', grad_fn=<AddBackward0>)
# 228 : tensor(0.0096, device='mps:0', grad_fn=<AddBackward0>)
# 229 : tensor(0.0085, device='mps:0', grad_fn=<AddBackward0>)
# 230 : tensor(0.0071, device='mps:0', grad_fn=<AddBackward0>)
# 231 : tensor(0.0084, device='mps:0', grad_fn=<AddBackward0>)
# 232 : tensor(0.0077, device='mps:0', grad_fn=<AddBackward0>)
# 233 : tensor(0.0059, device='mps:0', grad_fn=<AddBackward0>)
# 234 : tensor(0.0075, device='mps:0', grad_fn=<AddBackward0>)
# 235 : tensor(0.0062, device='mps:0', grad_fn=<AddBackward0>)
# 236 : tensor(0.0067, device='mps:0', grad_fn=<AddBackward0>)
# 237 : tensor(0.0046, device='mps:0', grad_fn=<AddBackward0>)
# 238 : tensor(0.0056, device='mps:0', grad_fn=<AddBackward0>)
# 239 : tensor(0.0095, device='mps:0', grad_fn=<AddBackward0>)
# 240 : tensor(0.0068, device='mps:0', grad_fn=<AddBackward0>)
# 241 : tensor(0.0057, device='mps:0', grad_fn=<AddBackward0>)
# 242 : tensor(0.0078, device='mps:0', grad_fn=<AddBackward0>)
# 243 : tensor(0.0056, device='mps:0', grad_fn=<AddBackward0>)
# 244 : tensor(0.0060, device='mps:0', grad_fn=<AddBackward0>)
# 245 : tensor(0.0059, device='mps:0', grad_fn=<AddBackward0>)
# 246 : tensor(0.0063, device='mps:0', grad_fn=<AddBackward0>)
# 247 : tensor(0.0069, device='mps:0', grad_fn=<AddBackward0>)
# 248 : tensor(0.0071, device='mps:0', grad_fn=<AddBackward0>)
# 249 : tensor(0.0044, device='mps:0', grad_fn=<AddBackward0>)
# 250 : tensor(0.0049, device='mps:0', grad_fn=<AddBackward0>)
# 251 : tensor(0.0039, device='mps:0', grad_fn=<AddBackward0>)
# 252 : tensor(0.0042, device='mps:0', grad_fn=<AddBackward0>)
# 253 : tensor(0.0046, device='mps:0', grad_fn=<AddBackward0>)
# 254 : tensor(0.0037, device='mps:0', grad_fn=<AddBackward0>)
# 255 : tensor(0.0039, device='mps:0', grad_fn=<AddBackward0>)
# 256 : tensor(0.0049, device='mps:0', grad_fn=<AddBackward0>)
# 257 : tensor(0.0049, device='mps:0', grad_fn=<AddBackward0>)
# 258 : tensor(0.0049, device='mps:0', grad_fn=<AddBackward0>)
# 259 : tensor(0.0046, device='mps:0', grad_fn=<AddBackward0>)
# 260 : tensor(0.0049, device='mps:0', grad_fn=<AddBackward0>)
# 261 : tensor(0.0049, device='mps:0', grad_fn=<AddBackward0>)
# 262 : tensor(0.0042, device='mps:0', grad_fn=<AddBackward0>)
# 263 : tensor(0.0039, device='mps:0', grad_fn=<AddBackward0>)
# 264 : tensor(0.0046, device='mps:0', grad_fn=<AddBackward0>)
# 265 : tensor(0.0051, device='mps:0', grad_fn=<AddBackward0>)
# 266 : tensor(0.0045, device='mps:0', grad_fn=<AddBackward0>)
# 267 : tensor(0.0044, device='mps:0', grad_fn=<AddBackward0>)
# 268 : tensor(0.0046, device='mps:0', grad_fn=<AddBackward0>)
# 269 : tensor(0.0051, device='mps:0', grad_fn=<AddBackward0>)
# 270 : tensor(0.0038, device='mps:0', grad_fn=<AddBackward0>)
# 271 : tensor(0.0035, device='mps:0', grad_fn=<AddBackward0>)
# 272 : tensor(0.0047, device='mps:0', grad_fn=<AddBackward0>)
# 273 : tensor(0.0045, device='mps:0', grad_fn=<AddBackward0>)
# 274 : tensor(0.0040, device='mps:0', grad_fn=<AddBackward0>)
# 275 : tensor(0.0042, device='mps:0', grad_fn=<AddBackward0>)
# 276 : tensor(0.0047, device='mps:0', grad_fn=<AddBackward0>)
# 277 : tensor(0.0055, device='mps:0', grad_fn=<AddBackward0>)
# 278 : tensor(0.0030, device='mps:0', grad_fn=<AddBackward0>)
# 279 : tensor(0.0046, device='mps:0', grad_fn=<AddBackward0>)
# 280 : tensor(0.0031, device='mps:0', grad_fn=<AddBackward0>)
# 281 : tensor(0.0036, device='mps:0', grad_fn=<AddBackward0>)
# 282 : tensor(0.0031, device='mps:0', grad_fn=<AddBackward0>)
# 283 : tensor(0.0031, device='mps:0', grad_fn=<AddBackward0>)
# 284 : tensor(0.0034, device='mps:0', grad_fn=<AddBackward0>)
# 285 : tensor(0.0041, device='mps:0', grad_fn=<AddBackward0>)
# 286 : tensor(0.0042, device='mps:0', grad_fn=<AddBackward0>)
# 287 : tensor(0.0045, device='mps:0', grad_fn=<AddBackward0>)
# 288 : tensor(0.0033, device='mps:0', grad_fn=<AddBackward0>)
# 289 : tensor(0.0047, device='mps:0', grad_fn=<AddBackward0>)
# 290 : tensor(0.0034, device='mps:0', grad_fn=<AddBackward0>)
# 291 : tensor(0.0034, device='mps:0', grad_fn=<AddBackward0>)
# 292 : tensor(0.0050, device='mps:0', grad_fn=<AddBackward0>)
# 293 : tensor(0.0035, device='mps:0', grad_fn=<AddBackward0>)
# 294 : tensor(0.0040, device='mps:0', grad_fn=<AddBackward0>)
# 295 : tensor(0.0038, device='mps:0', grad_fn=<AddBackward0>)
# 296 : tensor(0.0038, device='mps:0', grad_fn=<AddBackward0>)
# 297 : tensor(0.0035, device='mps:0', grad_fn=<AddBackward0>)
# 298 : tensor(0.0042, device='mps:0', grad_fn=<AddBackward0>)
# 299 : tensor(0.0030, device='mps:0', grad_fn=<AddBackward0>)
# 300 : tensor(0.0035, device='mps:0', grad_fn=<AddBackward0>)
# Training epoch 300
# Error tensor(nan, device='mps:0')
# 301 : tensor(0.0031, device='mps:0', grad_fn=<AddBackward0>)
# 302 : tensor(0.0030, device='mps:0', grad_fn=<AddBackward0>)
# 303 : tensor(0.0029, device='mps:0', grad_fn=<AddBackward0>)
# 304 : tensor(0.0038, device='mps:0', grad_fn=<AddBackward0>)
# 305 : tensor(0.0047, device='mps:0', grad_fn=<AddBackward0>)
# 306 : tensor(0.0023, device='mps:0', grad_fn=<AddBackward0>)
# 307 : tensor(0.0031, device='mps:0', grad_fn=<AddBackward0>)
# 308 : tensor(0.0041, device='mps:0', grad_fn=<AddBackward0>)
# 309 : tensor(0.0032, device='mps:0', grad_fn=<AddBackward0>)
# 310 : tensor(0.0029, device='mps:0', grad_fn=<AddBackward0>)
# 311 : tensor(0.0037, device='mps:0', grad_fn=<AddBackward0>)
# 312 : tensor(0.0031, device='mps:0', grad_fn=<AddBackward0>)
# 313 : tensor(0.0032, device='mps:0', grad_fn=<AddBackward0>)
# 314 : tensor(0.0035, device='mps:0', grad_fn=<AddBackward0>)
# 315 : tensor(0.0032, device='mps:0', grad_fn=<AddBackward0>)
# 316 : tensor(0.0034, device='mps:0', grad_fn=<AddBackward0>)
# 317 : tensor(0.0034, device='mps:0', grad_fn=<AddBackward0>)
# 318 : tensor(0.0033, device='mps:0', grad_fn=<AddBackward0>)
# 319 : tensor(0.0027, device='mps:0', grad_fn=<AddBackward0>)
# 320 : tensor(0.0027, device='mps:0', grad_fn=<AddBackward0>)
# 321 : tensor(0.0029, device='mps:0', grad_fn=<AddBackward0>)
# 322 : tensor(0.0025, device='mps:0', grad_fn=<AddBackward0>)
# 323 : tensor(0.0028, device='mps:0', grad_fn=<AddBackward0>)
# 324 : tensor(0.0037, device='mps:0', grad_fn=<AddBackward0>)
# 325 : tensor(0.0028, device='mps:0', grad_fn=<AddBackward0>)
# 326 : tensor(0.0032, device='mps:0', grad_fn=<AddBackward0>)
# 327 : tensor(0.0030, device='mps:0', grad_fn=<AddBackward0>)
# 328 : tensor(0.0036, device='mps:0', grad_fn=<AddBackward0>)
# 329 : tensor(0.0030, device='mps:0', grad_fn=<AddBackward0>)
# 330 : tensor(0.0030, device='mps:0', grad_fn=<AddBackward0>)
# 331 : tensor(0.0030, device='mps:0', grad_fn=<AddBackward0>)
# 332 : tensor(0.0033, device='mps:0', grad_fn=<AddBackward0>)
# 333 : tensor(0.0027, device='mps:0', grad_fn=<AddBackward0>)
# 334 : tensor(0.0023, device='mps:0', grad_fn=<AddBackward0>)
# 335 : tensor(0.0031, device='mps:0', grad_fn=<AddBackward0>)
# 336 : tensor(0.0026, device='mps:0', grad_fn=<AddBackward0>)
# 337 : tensor(0.0036, device='mps:0', grad_fn=<AddBackward0>)
# 338 : tensor(0.0033, device='mps:0', grad_fn=<AddBackward0>)
# 339 : tensor(0.0029, device='mps:0', grad_fn=<AddBackward0>)
# 340 : tensor(0.0027, device='mps:0', grad_fn=<AddBackward0>)
# 341 : tensor(0.0040, device='mps:0', grad_fn=<AddBackward0>)
# 342 : tensor(0.0024, device='mps:0', grad_fn=<AddBackward0>)
# 343 : tensor(0.0035, device='mps:0', grad_fn=<AddBackward0>)
# 344 : tensor(0.0029, device='mps:0', grad_fn=<AddBackward0>)
# 345 : tensor(0.0027, device='mps:0', grad_fn=<AddBackward0>)
# 346 : tensor(0.0033, device='mps:0', grad_fn=<AddBackward0>)
# 347 : tensor(0.0028, device='mps:0', grad_fn=<AddBackward0>)
# 348 : tensor(0.0027, device='mps:0', grad_fn=<AddBackward0>)
# 349 : tensor(0.0025, device='mps:0', grad_fn=<AddBackward0>)
# 350 : tensor(0.0032, device='mps:0', grad_fn=<AddBackward0>)
# 351 : tensor(0.0034, device='mps:0', grad_fn=<AddBackward0>)
# 352 : tensor(0.0034, device='mps:0', grad_fn=<AddBackward0>)
# 353 : tensor(0.0025, device='mps:0', grad_fn=<AddBackward0>)
# 354 : tensor(0.0023, device='mps:0', grad_fn=<AddBackward0>)
# 355 : tensor(0.0025, device='mps:0', grad_fn=<AddBackward0>)
# 356 : tensor(0.0029, device='mps:0', grad_fn=<AddBackward0>)
# 357 : tensor(0.0022, device='mps:0', grad_fn=<AddBackward0>)
# 358 : tensor(0.0036, device='mps:0', grad_fn=<AddBackward0>)
# 359 : tensor(0.0033, device='mps:0', grad_fn=<AddBackward0>)
# 360 : tensor(0.0027, device='mps:0', grad_fn=<AddBackward0>)
# 361 : tensor(0.0030, device='mps:0', grad_fn=<AddBackward0>)
# 362 : tensor(0.0028, device='mps:0', grad_fn=<AddBackward0>)
# 363 : tensor(0.0034, device='mps:0', grad_fn=<AddBackward0>)
# 364 : tensor(0.0030, device='mps:0', grad_fn=<AddBackward0>)
# 365 : tensor(0.0033, device='mps:0', grad_fn=<AddBackward0>)
# 366 : tensor(0.0033, device='mps:0', grad_fn=<AddBackward0>)
# 367 : tensor(0.0024, device='mps:0', grad_fn=<AddBackward0>)
# 368 : tensor(0.0026, device='mps:0', grad_fn=<AddBackward0>)
# 369 : tensor(0.0032, device='mps:0', grad_fn=<AddBackward0>)
# 370 : tensor(0.0033, device='mps:0', grad_fn=<AddBackward0>)
# 371 : tensor(0.0025, device='mps:0', grad_fn=<AddBackward0>)
# 372 : tensor(0.0031, device='mps:0', grad_fn=<AddBackward0>)
# 373 : tensor(0.0031, device='mps:0', grad_fn=<AddBackward0>)
# 374 : tensor(0.0024, device='mps:0', grad_fn=<AddBackward0>)
# 375 : tensor(0.0035, device='mps:0', grad_fn=<AddBackward0>)
# 376 : tensor(0.0025, device='mps:0', grad_fn=<AddBackward0>)
# 377 : tensor(0.0040, device='mps:0', grad_fn=<AddBackward0>)
# 378 : tensor(0.0034, device='mps:0', grad_fn=<AddBackward0>)
# 379 : tensor(0.0028, device='mps:0', grad_fn=<AddBackward0>)
# 380 : tensor(0.0032, device='mps:0', grad_fn=<AddBackward0>)
# 381 : tensor(0.0027, device='mps:0', grad_fn=<AddBackward0>)
# 382 : tensor(0.0034, device='mps:0', grad_fn=<AddBackward0>)
# 383 : tensor(0.0032, device='mps:0', grad_fn=<AddBackward0>)
# 384 : tensor(0.0030, device='mps:0', grad_fn=<AddBackward0>)
# 385 : tensor(0.0031, device='mps:0', grad_fn=<AddBackward0>)
# 386 : tensor(0.0040, device='mps:0', grad_fn=<AddBackward0>)
# 387 : tensor(0.0029, device='mps:0', grad_fn=<AddBackward0>)
# 388 : tensor(0.0033, device='mps:0', grad_fn=<AddBackward0>)
# 389 : tensor(0.0040, device='mps:0', grad_fn=<AddBackward0>)
# 390 : tensor(0.0028, device='mps:0', grad_fn=<AddBackward0>)
# 391 : tensor(0.0026, device='mps:0', grad_fn=<AddBackward0>)
# 392 : tensor(0.0030, device='mps:0', grad_fn=<AddBackward0>)
# 393 : tensor(0.0025, device='mps:0', grad_fn=<AddBackward0>)
# 394 : tensor(0.0030, device='mps:0', grad_fn=<AddBackward0>)
# 395 : tensor(0.0028, device='mps:0', grad_fn=<AddBackward0>)
# 396 : tensor(0.0025, device='mps:0', grad_fn=<AddBackward0>)
# 397 : tensor(0.0024, device='mps:0', grad_fn=<AddBackward0>)
# 398 : tensor(0.0034, device='mps:0', grad_fn=<AddBackward0>)
# 399 : tensor(0.0034, device='mps:0', grad_fn=<AddBackward0>)
# 400 : tensor(0.0027, device='mps:0', grad_fn=<AddBackward0>)
# Training epoch 400
# Error tensor(nan, device='mps:0')
# 401 : tensor(0.0038, device='mps:0', grad_fn=<AddBackward0>)
# 402 : tensor(0.0028, device='mps:0', grad_fn=<AddBackward0>)
# 403 : tensor(0.0029, device='mps:0', grad_fn=<AddBackward0>)
# 404 : tensor(0.0034, device='mps:0', grad_fn=<AddBackward0>)
# 405 : tensor(0.0037, device='mps:0', grad_fn=<AddBackward0>)
# 406 : tensor(0.0039, device='mps:0', grad_fn=<AddBackward0>)
# 407 : tensor(0.0023, device='mps:0', grad_fn=<AddBackward0>)
# 408 : tensor(0.0030, device='mps:0', grad_fn=<AddBackward0>)
# 409 : tensor(0.0027, device='mps:0', grad_fn=<AddBackward0>)
# 410 : tensor(0.0031, device='mps:0', grad_fn=<AddBackward0>)
# 411 : tensor(0.0024, device='mps:0', grad_fn=<AddBackward0>)
# 412 : tensor(0.0034, device='mps:0', grad_fn=<AddBackward0>)
# 413 : tensor(0.0025, device='mps:0', grad_fn=<AddBackward0>)
# 414 : tensor(0.0031, device='mps:0', grad_fn=<AddBackward0>)
# 415 : tensor(0.0033, device='mps:0', grad_fn=<AddBackward0>)
# 416 : tensor(0.0032, device='mps:0', grad_fn=<AddBackward0>)
# 417 : tensor(0.0028, device='mps:0', grad_fn=<AddBackward0>)
# 418 : tensor(0.0024, device='mps:0', grad_fn=<AddBackward0>)
# 419 : tensor(0.0030, device='mps:0', grad_fn=<AddBackward0>)
# 420 : tensor(0.0031, device='mps:0', grad_fn=<AddBackward0>)
# 421 : tensor(0.0025, device='mps:0', grad_fn=<AddBackward0>)
# 422 : tensor(0.0031, device='mps:0', grad_fn=<AddBackward0>)
# 423 : tensor(0.0028, device='mps:0', grad_fn=<AddBackward0>)
# 424 : tensor(0.0026, device='mps:0', grad_fn=<AddBackward0>)
# 425 : tensor(0.0033, device='mps:0', grad_fn=<AddBackward0>)
# 426 : tensor(0.0019, device='mps:0', grad_fn=<AddBackward0>)
# 427 : tensor(0.0025, device='mps:0', grad_fn=<AddBackward0>)
# 428 : tensor(0.0025, device='mps:0', grad_fn=<AddBackward0>)
# 429 : tensor(0.0030, device='mps:0', grad_fn=<AddBackward0>)
# 430 : tensor(0.0031, device='mps:0', grad_fn=<AddBackward0>)
# 431 : tensor(0.0033, device='mps:0', grad_fn=<AddBackward0>)
# 432 : tensor(0.0030, device='mps:0', grad_fn=<AddBackward0>)
# 433 : tensor(0.0031, device='mps:0', grad_fn=<AddBackward0>)
# 434 : tensor(0.0031, device='mps:0', grad_fn=<AddBackward0>)
# 435 : tensor(0.0027, device='mps:0', grad_fn=<AddBackward0>)
# 436 : tensor(0.0038, device='mps:0', grad_fn=<AddBackward0>)
# 437 : tensor(0.0026, device='mps:0', grad_fn=<AddBackward0>)
# 438 : tensor(0.0023, device='mps:0', grad_fn=<AddBackward0>)
# 439 : tensor(0.0024, device='mps:0', grad_fn=<AddBackward0>)
# 440 : tensor(0.0035, device='mps:0', grad_fn=<AddBackward0>)
# 441 : tensor(0.0031, device='mps:0', grad_fn=<AddBackward0>)
# 442 : tensor(0.0022, device='mps:0', grad_fn=<AddBackward0>)
# 443 : tensor(0.0044, device='mps:0', grad_fn=<AddBackward0>)
# 444 : tensor(0.0027, device='mps:0', grad_fn=<AddBackward0>)
# 445 : tensor(0.0023, device='mps:0', grad_fn=<AddBackward0>)
# 446 : tensor(0.0030, device='mps:0', grad_fn=<AddBackward0>)
# 447 : tensor(0.0030, device='mps:0', grad_fn=<AddBackward0>)
# 448 : tensor(0.0022, device='mps:0', grad_fn=<AddBackward0>)
# 449 : tensor(0.0024, device='mps:0', grad_fn=<AddBackward0>)
# 450 : tensor(0.0034, device='mps:0', grad_fn=<AddBackward0>)
# 451 : tensor(0.0033, device='mps:0', grad_fn=<AddBackward0>)
# 452 : tensor(0.0032, device='mps:0', grad_fn=<AddBackward0>)
# 453 : tensor(0.0029, device='mps:0', grad_fn=<AddBackward0>)
# 454 : tensor(0.0030, device='mps:0', grad_fn=<AddBackward0>)
# 455 : tensor(0.0020, device='mps:0', grad_fn=<AddBackward0>)
# 456 : tensor(0.0030, device='mps:0', grad_fn=<AddBackward0>)
# 457 : tensor(0.0024, device='mps:0', grad_fn=<AddBackward0>)
# 458 : tensor(0.0035, device='mps:0', grad_fn=<AddBackward0>)
# 459 : tensor(0.0028, device='mps:0', grad_fn=<AddBackward0>)
# 460 : tensor(0.0026, device='mps:0', grad_fn=<AddBackward0>)
# 461 : tensor(0.0020, device='mps:0', grad_fn=<AddBackward0>)
# 462 : tensor(0.0029, device='mps:0', grad_fn=<AddBackward0>)
# 463 : tensor(0.0027, device='mps:0', grad_fn=<AddBackward0>)
# 464 : tensor(0.0025, device='mps:0', grad_fn=<AddBackward0>)
# 465 : tensor(0.0031, device='mps:0', grad_fn=<AddBackward0>)
# 466 : tensor(0.0028, device='mps:0', grad_fn=<AddBackward0>)
# 467 : tensor(0.0025, device='mps:0', grad_fn=<AddBackward0>)
# 468 : tensor(0.0026, device='mps:0', grad_fn=<AddBackward0>)
# 469 : tensor(0.0029, device='mps:0', grad_fn=<AddBackward0>)
# 470 : tensor(0.0026, device='mps:0', grad_fn=<AddBackward0>)
# 471 : tensor(0.0023, device='mps:0', grad_fn=<AddBackward0>)
# 472 : tensor(0.0029, device='mps:0', grad_fn=<AddBackward0>)
# 473 : tensor(0.0027, device='mps:0', grad_fn=<AddBackward0>)
# 474 : tensor(0.0032, device='mps:0', grad_fn=<AddBackward0>)
# 475 : tensor(0.0019, device='mps:0', grad_fn=<AddBackward0>)
# 476 : tensor(0.0037, device='mps:0', grad_fn=<AddBackward0>)
# 477 : tensor(0.0029, device='mps:0', grad_fn=<AddBackward0>)
# 478 : tensor(0.0025, device='mps:0', grad_fn=<AddBackward0>)
# 479 : tensor(0.0028, device='mps:0', grad_fn=<AddBackward0>)
# 480 : tensor(0.0023, device='mps:0', grad_fn=<AddBackward0>)
# 481 : tensor(0.0022, device='mps:0', grad_fn=<AddBackward0>)
# 482 : tensor(0.0031, device='mps:0', grad_fn=<AddBackward0>)
# 483 : tensor(0.0025, device='mps:0', grad_fn=<AddBackward0>)
# 484 : tensor(0.0026, device='mps:0', grad_fn=<AddBackward0>)
# 485 : tensor(0.0022, device='mps:0', grad_fn=<AddBackward0>)
# 486 : tensor(0.0025, device='mps:0', grad_fn=<AddBackward0>)
# 487 : tensor(0.0034, device='mps:0', grad_fn=<AddBackward0>)
# 488 : tensor(0.0026, device='mps:0', grad_fn=<AddBackward0>)
# 489 : tensor(0.0022, device='mps:0', grad_fn=<AddBackward0>)
# 490 : tensor(0.0024, device='mps:0', grad_fn=<AddBackward0>)
# 491 : tensor(0.0024, device='mps:0', grad_fn=<AddBackward0>)
# 492 : tensor(0.0024, device='mps:0', grad_fn=<AddBackward0>)
# 493 : tensor(0.0025, device='mps:0', grad_fn=<AddBackward0>)
# 494 : tensor(0.0028, device='mps:0', grad_fn=<AddBackward0>)
# 495 : tensor(0.0028, device='mps:0', grad_fn=<AddBackward0>)
# 496 : tensor(0.0028, device='mps:0', grad_fn=<AddBackward0>)
# 497 : tensor(0.0024, device='mps:0', grad_fn=<AddBackward0>)
# 498 : tensor(0.0027, device='mps:0', grad_fn=<AddBackward0>)
# 499 : tensor(0.0025, device='mps:0', grad_fn=<AddBackward0>)
# 500 : tensor(0.0031, device='mps:0', grad_fn=<AddBackward0>)
# Training epoch 500
# Error tensor(nan, device='mps:0')
# 501 : tensor(0.0019, device='mps:0', grad_fn=<AddBackward0>)
# 502 : tensor(0.0023, device='mps:0', grad_fn=<AddBackward0>)
# 503 : tensor(0.0030, device='mps:0', grad_fn=<AddBackward0>)
# 504 : tensor(0.0023, device='mps:0', grad_fn=<AddBackward0>)
# 505 : tensor(0.0026, device='mps:0', grad_fn=<AddBackward0>)
# 506 : tensor(0.0032, device='mps:0', grad_fn=<AddBackward0>)
# 507 : tensor(0.0028, device='mps:0', grad_fn=<AddBackward0>)
# 508 : tensor(0.0022, device='mps:0', grad_fn=<AddBackward0>)
# 509 : tensor(0.0028, device='mps:0', grad_fn=<AddBackward0>)
# 510 : tensor(0.0025, device='mps:0', grad_fn=<AddBackward0>)
# 511 : tensor(0.0023, device='mps:0', grad_fn=<AddBackward0>)
# 512 : tensor(0.0024, device='mps:0', grad_fn=<AddBackward0>)
# 513 : tensor(0.0025, device='mps:0', grad_fn=<AddBackward0>)
# 514 : tensor(0.0026, device='mps:0', grad_fn=<AddBackward0>)
# 515 : tensor(0.0026, device='mps:0', grad_fn=<AddBackward0>)
# 516 : tensor(0.0023, device='mps:0', grad_fn=<AddBackward0>)
# 517 : tensor(0.0031, device='mps:0', grad_fn=<AddBackward0>)
# 518 : tensor(0.0026, device='mps:0', grad_fn=<AddBackward0>)
# 519 : tensor(0.0023, device='mps:0', grad_fn=<AddBackward0>)
# 520 : tensor(0.0022, device='mps:0', grad_fn=<AddBackward0>)
# 521 : tensor(0.0027, device='mps:0', grad_fn=<AddBackward0>)
# 522 : tensor(0.0026, device='mps:0', grad_fn=<AddBackward0>)
# 523 : tensor(0.0027, device='mps:0', grad_fn=<AddBackward0>)
# 524 : tensor(0.0024, device='mps:0', grad_fn=<AddBackward0>)
# 525 : tensor(0.0026, device='mps:0', grad_fn=<AddBackward0>)
# 526 : tensor(0.0020, device='mps:0', grad_fn=<AddBackward0>)
# 527 : tensor(0.0019, device='mps:0', grad_fn=<AddBackward0>)
# 528 : tensor(0.0027, device='mps:0', grad_fn=<AddBackward0>)
# 529 : tensor(0.0021, device='mps:0', grad_fn=<AddBackward0>)
# 530 : tensor(0.0021, device='mps:0', grad_fn=<AddBackward0>)
# 531 : tensor(0.0024, device='mps:0', grad_fn=<AddBackward0>)
# 532 : tensor(0.0024, device='mps:0', grad_fn=<AddBackward0>)
# 533 : tensor(0.0023, device='mps:0', grad_fn=<AddBackward0>)
# 534 : tensor(0.0017, device='mps:0', grad_fn=<AddBackward0>)
# 535 : tensor(0.0025, device='mps:0', grad_fn=<AddBackward0>)
# 536 : tensor(0.0026, device='mps:0', grad_fn=<AddBackward0>)
# 537 : tensor(0.0019, device='mps:0', grad_fn=<AddBackward0>)
# 538 : tensor(0.0023, device='mps:0', grad_fn=<AddBackward0>)
# 539 : tensor(0.0029, device='mps:0', grad_fn=<AddBackward0>)
# 540 : tensor(0.0028, device='mps:0', grad_fn=<AddBackward0>)
# 541 : tensor(0.0024, device='mps:0', grad_fn=<AddBackward0>)
# 542 : tensor(0.0022, device='mps:0', grad_fn=<AddBackward0>)
# 543 : tensor(0.0026, device='mps:0', grad_fn=<AddBackward0>)
# 544 : tensor(0.0027, device='mps:0', grad_fn=<AddBackward0>)
# 545 : tensor(0.0024, device='mps:0', grad_fn=<AddBackward0>)
# 546 : tensor(0.0023, device='mps:0', grad_fn=<AddBackward0>)
# 547 : tensor(0.0022, device='mps:0', grad_fn=<AddBackward0>)
# 548 : tensor(0.0024, device='mps:0', grad_fn=<AddBackward0>)
# 549 : tensor(0.0022, device='mps:0', grad_fn=<AddBackward0>)
# 550 : tensor(0.0019, device='mps:0', grad_fn=<AddBackward0>)
# 551 : tensor(0.0024, device='mps:0', grad_fn=<AddBackward0>)
# 552 : tensor(0.0017, device='mps:0', grad_fn=<AddBackward0>)
# 553 : tensor(0.0023, device='mps:0', grad_fn=<AddBackward0>)
# 554 : tensor(0.0028, device='mps:0', grad_fn=<AddBackward0>)
# 555 : tensor(0.0022, device='mps:0', grad_fn=<AddBackward0>)
# 556 : tensor(0.0026, device='mps:0', grad_fn=<AddBackward0>)
# 557 : tensor(0.0024, device='mps:0', grad_fn=<AddBackward0>)
# 558 : tensor(0.0017, device='mps:0', grad_fn=<AddBackward0>)
# 559 : tensor(0.0023, device='mps:0', grad_fn=<AddBackward0>)
# 560 : tensor(0.0029, device='mps:0', grad_fn=<AddBackward0>)
# 561 : tensor(0.0026, device='mps:0', grad_fn=<AddBackward0>)
# 562 : tensor(0.0021, device='mps:0', grad_fn=<AddBackward0>)
# 563 : tensor(0.0026, device='mps:0', grad_fn=<AddBackward0>)
# 564 : tensor(0.0031, device='mps:0', grad_fn=<AddBackward0>)
# 565 : tensor(0.0024, device='mps:0', grad_fn=<AddBackward0>)
# 566 : tensor(0.0022, device='mps:0', grad_fn=<AddBackward0>)
# 567 : tensor(0.0024, device='mps:0', grad_fn=<AddBackward0>)
# 568 : tensor(0.0024, device='mps:0', grad_fn=<AddBackward0>)
# 569 : tensor(0.0021, device='mps:0', grad_fn=<AddBackward0>)
# 570 : tensor(0.0026, device='mps:0', grad_fn=<AddBackward0>)
# 571 : tensor(0.0020, device='mps:0', grad_fn=<AddBackward0>)
# 572 : tensor(0.0020, device='mps:0', grad_fn=<AddBackward0>)
# 573 : tensor(0.0022, device='mps:0', grad_fn=<AddBackward0>)
# 574 : tensor(0.0021, device='mps:0', grad_fn=<AddBackward0>)
# 575 : tensor(0.0033, device='mps:0', grad_fn=<AddBackward0>)
# 576 : tensor(0.0025, device='mps:0', grad_fn=<AddBackward0>)
# 577 : tensor(0.0021, device='mps:0', grad_fn=<AddBackward0>)
# 578 : tensor(0.0022, device='mps:0', grad_fn=<AddBackward0>)
# 579 : tensor(0.0019, device='mps:0', grad_fn=<AddBackward0>)
# 580 : tensor(0.0024, device='mps:0', grad_fn=<AddBackward0>)
# 581 : tensor(0.0020, device='mps:0', grad_fn=<AddBackward0>)
# 582 : tensor(0.0023, device='mps:0', grad_fn=<AddBackward0>)
# 583 : tensor(0.0028, device='mps:0', grad_fn=<AddBackward0>)
# 584 : tensor(0.0024, device='mps:0', grad_fn=<AddBackward0>)
# 585 : tensor(0.0023, device='mps:0', grad_fn=<AddBackward0>)
# 586 : tensor(0.0021, device='mps:0', grad_fn=<AddBackward0>)
# 587 : tensor(0.0021, device='mps:0', grad_fn=<AddBackward0>)
# 588 : tensor(0.0027, device='mps:0', grad_fn=<AddBackward0>)
# 589 : tensor(0.0026, device='mps:0', grad_fn=<AddBackward0>)
# 590 : tensor(0.0023, device='mps:0', grad_fn=<AddBackward0>)
# 591 : tensor(0.0029, device='mps:0', grad_fn=<AddBackward0>)
# 592 : tensor(0.0021, device='mps:0', grad_fn=<AddBackward0>)
# 593 : tensor(0.0026, device='mps:0', grad_fn=<AddBackward0>)
# 594 : tensor(0.0028, device='mps:0', grad_fn=<AddBackward0>)
# 595 : tensor(0.0026, device='mps:0', grad_fn=<AddBackward0>)
# 596 : tensor(0.0026, device='mps:0', grad_fn=<AddBackward0>)
# 597 : tensor(0.0023, device='mps:0', grad_fn=<AddBackward0>)
# 598 : tensor(0.0017, device='mps:0', grad_fn=<AddBackward0>)
# 599 : tensor(0.0025, device='mps:0', grad_fn=<AddBackward0>)
# 600 : tensor(0.0024, device='mps:0', grad_fn=<AddBackward0>)
# Training epoch 600
# Error tensor(nan, device='mps:0')

# %% [markdown]
# ## 4. SINDy Discovery
#
# Discover sparse governing equations from the learned latent space.

# %%
os.chdir("/Users/karllapo/Library/CloudStorage/Dropbox/ESPRIT/proj/notebooks/mr-SHRED/mr-SHRED/mr-SHRED")
from sindy_utils import MIOSR

os.chdir("/Users/karllapo/Library/CloudStorage/Dropbox/ESPRIT/proj/notebooks/sindy-shred/sindy-shred/")
import miosr_utils

order = 2
group_sparsity = np.ones(latent_dim) * order
group_sparsity = np.append(group_sparsity, np.ones(latent_dim) * order)

optimizer_kwargs = {"alpha": 0.05, "group_sparsity": group_sparsity}
optimizer = MIOSR

# %%
model._ode_order
# Out:
# 2

# %%
miosr_utils.sindy_identify(model, optimizer=optimizer, optimizer_kwargs=optimizer_kwargs)
# Out:
# SINDy-derived dynamical equation (2nd order, state-space form):
#
# State: [z_0, ..., z_{n-1}, v_0, ..., v_{n-1}]
# where v = dz/dt
#
# (x0)' = 1.000 x1
# (x1)' = -0.329 x0 + -0.350 x0 x1

# %%
# Perform SINDy identification with automatic plot saving
model.sindy_identify(
    threshold=0.15, plot_result=True)#, save_path=f"{RESULTS_DIR}/latent_comparison"
# )
# print(f"Saved latent comparison plot to {RESULTS_DIR}/latent_comparison.png")
# Out:
# SINDy-derived dynamical equation (2nd order, state-space form):
#
# State: [z_0, ..., z_{n-1}, v_0, ..., v_{n-1}]
# where v = dz/dt
#
# (x0)' = 1.000 x1
# (x1)' = -0.330 x0 + -0.453 x0 x1 + 0.161 x1^2

# %%
plt.figure(figsize=(10, 2))
plt.plot(solution_vdp.y.T[:len(time) * substep // 2])
# Out:
# [<matplotlib.lines.Line2D at 0x366a96c50>,
#  <matplotlib.lines.Line2D at 0x366e38910>]

# %% [markdown]
# ### Auto-Tune Threshold (Adaptive/Nonparametric)
#
# Alternatively, use `auto_tune_threshold()` to automatically determine the best threshold.
# By default it uses a nonparametric approach:
# 1. First computes the least-squares solution (threshold=0)
# 2. Uses `scale_factor * max(|coefficients|)` as the max threshold
# 3. Tests `n_thresholds` evenly spaced values and picks the best stable model

# %%
os.chdir("/Users/karllapo/Library/CloudStorage/Dropbox/ESPRIT/proj/notebooks/mr-SHRED/mr-SHRED/mr-SHRED")
from sindy_utils import MIOSR

order = 3
group_sparsity = np.ones(latent_dim) * order
group_sparsity = np.append(group_sparsity, np.ones(latent_dim) * order)

# optimizer_kwargs = {"alpha": 0.05, "group_sparsity": group_sparsity}
# optimizer = MIOSR

optimizer_kwargs = None
optimizer = None

# Auto-tune threshold using nonparametric approach
# This computes least-squares solution first, then determines threshold range adaptively
best_threshold, tune_results = model.auto_tune_threshold(
    adaptive=True,  # Use nonparametric approach (default)
    scale_factor=.2,  # Max threshold = 0.3 * max(|coefficients|)
    n_thresholds=10,  # Test 10 evenly spaced thresholds
    metric="sparsity_stable",  # Pick sparsest stable model
    verbose=True,
    optimizer=optimizer,
    optimizer_kwargs=optimizer_kwargs
)

print(f"\nBest threshold: {best_threshold:.4f}")
print(f"Tested thresholds: {tune_results['thresholds']}")
print(f"Sparsity at each: {tune_results['sparsity']}")
print(f"Stability at each: {tune_results['stable']}")
# Out:
# Computing least-squares solution to determine threshold range...
# Max |coefficient|: 1.0000
# Max threshold (scale_factor=0.2): 0.2000
# Testing 10 thresholds: [0.         0.0222222  0.0444444  0.0666666  0.08888879 0.11111099
#  0.13333319 0.15555539 0.17777759 0.19999979]
# Testing threshold=0.000...  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305571685261D+02   r2 =  0.7409605546462D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305571685261D+02   r2 =  0.7409605546462D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305571685261D+02   r2 =  0.7409605546462D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305571685261D+02   r2 =  0.7409605546462D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305571685261D+02   r2 =  0.7409605546462D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305571685261D+02   r2 =  0.7409605546462D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305571685261D+02   r2 =  0.7409605546462D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305571685261D+02   r2 =  0.7409605546462D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305571685261D+02   r2 =  0.7409605546462D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305571685261D+02   r2 =  0.7409605546462D-15
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
# sparsity=12, DIVERGED, MSE=inf
# Testing threshold=0.022...
# capi_return is NULL
# Call-back cb_f_in_lsoda__user__routines failed.
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
# sparsity=7, DIVERGED, MSE=inf
# Testing threshold=0.044...
# capi_return is NULL
# Call-back cb_f_in_lsoda__user__routines failed.
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
# sparsity=7, DIVERGED, MSE=inf
# Testing threshold=0.067...
# capi_return is NULL
# Call-back cb_f_in_lsoda__user__routines failed.
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
# sparsity=7, DIVERGED, MSE=inf
# Testing threshold=0.089...
# capi_return is NULL
# Call-back cb_f_in_lsoda__user__routines failed.
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
# sparsity=7, DIVERGED, MSE=inf
# Testing threshold=0.111...
# capi_return is NULL
# Call-back cb_f_in_lsoda__user__routines failed.
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1305570082757D+02   r2 =  0.8726071297066D-15
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
# sparsity=7, DIVERGED, MSE=inf
# Testing threshold=0.133...
# capi_return is NULL
# Call-back cb_f_in_lsoda__user__routines failed.
# sparsity=4, stable, MSE=2.4259e-01
# Testing threshold=0.156... sparsity=3, stable, MSE=2.8336e-01
# Testing threshold=0.178... sparsity=3, stable, MSE=2.8336e-01
# Testing threshold=0.200... sparsity=3, stable, MSE=2.8336e-01
#
# Best threshold: 0.156 (sparsity=3, MSE=2.8336e-01)
# SINDy-derived dynamical equation (2nd order, state-space form):
#
# State: [z_0, ..., z_{n-1}, v_0, ..., v_{n-1}]
# where v = dz/dt
#
# (x0)' = 1.000 x1
# (x1)' = -0.339 x0 + -0.425 x0 x1
#
# Best threshold: 0.1556
# Tested thresholds: [0.         0.0222222  0.0444444  0.0666666  0.08888879 0.11111099
#  0.13333319 0.15555539 0.17777759 0.19999979]
# Sparsity at each: [12  7  7  7  7  7  4  3  3  3]
# Stability at each: [False False False False False False  True  True  True  True]

# %% [markdown]
# ### True Governing Equations
#
# For reference, the true governing equations are:
#
# **FitzHugh-Nagumo Model:**
# $$\dot{v} = v - \frac{1}{3}v^3 - w + 0.65$$
# $$\dot{w} = \frac{1}{\tau}(v + 0.7 - 0.8w)$$
#
# with time constant $\tau = 2$.
#
# We recover a model that resembles the original model. A more accurate model for sensor reconstruction and prediction can be achieved using a lower threshold, but this model would admit additional governing terms that are not present in the original model and may represent an overfit. For this reason, the criterion weigh the information gained against the number of parameters required. Depending on your use case you may find different criteria important and one should weigh these trade-offs.

# %% [markdown]
# ## 5. Evaluation
#
# Evaluate reconstruction performance on the test set.

# %%
# Compute test reconstruction error using new API
test_recons = model.sensor_recon(data_type="test", return_scaled=False)
test_ground_truth = model._scaler.inverse_transform(
    model._test_data.Y.detach().cpu().numpy()
)

relative_error = model.relative_error(test_recons, test_ground_truth)
print(f"Test set relative reconstruction error: {relative_error:.4f}")
# Out:
# Test set relative reconstruction error: 0.0519

# %%
# Visualize reconstruction
fig, axes = plt.subplots(2, 1, figsize=(10, 5), sharex=True)

ax = axes[0]
ax.pcolormesh(test_ground_truth.T, **pcolor_kwargs)
ax.set_title("Ground Truth")
ax.set_ylabel("Space")

ax = axes[1]
ax.pcolormesh(test_recons.T, **pcolor_kwargs)
ax.set_title("SINDy-SHRED Reconstruction")
ax.set_ylabel("Space")
ax.set_xlabel("Time step")

fig.tight_layout()

# # Save the reconstruction comparison plot
# fig.savefig(
#     f"{RESULTS_DIR}/reconstruction_comparison.pdf", bbox_inches="tight", dpi=300
# )
# fig.savefig(
#     f"{RESULTS_DIR}/reconstruction_comparison.png", bbox_inches="tight", dpi=300
# )
# print(
#     f"Saved reconstruction comparison plot to {RESULTS_DIR}/reconstruction_comparison.pdf"
# )

plt.show()

# %% [markdown]
# ### Sensor-Level Predictions
#
# Compare real vs predicted at individual spatial locations (sensors).
#
# The **first approach** illustrates the overall work flow:
#
# - Predict the latent space by integrating the identified model forward in time. Initial condition is the last value of the training split's latent space trajectory.
# - Pass the latent space trajectories through the shallow decoder in order to map to the higher dimensional space.
# - Transform the higher dimensional data back to the original space.
#
# This approach can also be used to predict other time periods.
#
# The **second approach** combines all of the substeps from the first approach using a helper function.

# %%
# 1st approach: Predict latent trajectories using SINDy model and decode to physical space
x_predict = model.predict_latent(split="train", init_from="last")  # SINDy prediction in latent space
sindy_physical = model.decode_to_physical(x_predict)  # Decode to physical space
sindy_physical = model._scaler.inverse_transform(sindy_physical)  # Unscale

# 2nd approach: Directly forecast from the last training point.
sindy_physical = model.forecast(return_scaled=False)

print(f"SINDy prediction shape: {x_predict.shape}")
print(f"Decoded physical shape: {sindy_physical.shape}")

# Plot sensor-level comparisons: Ground Truth vs SINDy Prediction
fig, axes = plotting.plot_sensor_predictions(
    test_ground_truth,
    sindy_physical[: len(test_ground_truth)],
    sensor_locations=np.arange(n_space_dims),  # All spatial dims
    rows=2,
    cols=5,
    # save_path=f"{RESULTS_DIR}/sensor_predictions_grid.pdf",
)
fig.suptitle("Sensor-Level: Ground Truth vs SINDy Prediction")
fig.tight_layout()
# print(f"Saved sensor predictions plot to {RESULTS_DIR}/sensor_predictions_grid.pdf")
plt.show()
# Out:
# SINDy prediction shape: (183, 1)
# Decoded physical shape: (183, 40)

# %% [markdown]
# ## Summary
#
# This notebook demonstrated SINDy-SHRED on synthetic FitzHugh-Nagumo data:
#
# 1. Generated toy data from FitzHugh-Nagumo model with spatial delays
# 2. Used the `SINDySHRED` class for streamlined model training
# 3. Discovered sparse governing equations that approximate the true dynamics
# 4. Achieved accurate reconstruction on held-out test data
# 5. **Saved all results** to the `results/synthetic_data/` folder
#
# ### Saved Files
#
# | File | Description |
# |------|-------------|
# | `latent_train.npy` | Latent trajectories from training data |
# | `latent_test.npy` | Latent trajectories from test data |
# | `latent_sindy_predict.npy` | SINDy-predicted latent trajectories |
# | `sindy_coefficients.npy` | Learned SINDy coefficient matrix |
# | `sindy_feature_names.txt` | Names of SINDy library terms |
# | `config.json` | Model configuration and hyperparameters |
# | `results.json` | All error metrics (reconstruction, SINDy latent, SINDy prediction) |
# | `*.pdf/*.png` | Visualization plots |
#
# The `SINDySHRED` class simplifies the workflow compared to manual data preprocessing and model setup.

# %% [markdown]
# ## 6. Save Results
#
# Save the trained model, latent space values, and learned SINDy model to the results folder.

# %%
import json
import sys
from io import StringIO

# Get latent space trajectories
gru_outs_train = model.gru_normalize(data_type="train")
gru_outs_train_np = gru_outs_train.detach().cpu().numpy()

gru_outs_test = model.gru_normalize(data_type="test")
gru_outs_test_np = gru_outs_test.detach().cpu().numpy()

# Save latent space trajectories
np.save(f"{RESULTS_DIR}/latent_train.npy", gru_outs_train_np)
np.save(f"{RESULTS_DIR}/latent_test.npy", gru_outs_test_np)
np.save(f"{RESULTS_DIR}/latent_sindy_predict.npy", x_predict)
print(f"Saved latent trajectories to {RESULTS_DIR}/latent_*.npy")

# Save SINDy model coefficients
sindy_coefficients = model._model.coefficients()
np.save(f"{RESULTS_DIR}/sindy_coefficients.npy", sindy_coefficients)
print(f"Saved SINDy coefficients to {RESULTS_DIR}/sindy_coefficients.npy")
print(f"SINDy coefficients shape: {sindy_coefficients.shape}")

# Save SINDy feature names
feature_names = model._model.get_feature_names()
with open(f"{RESULTS_DIR}/sindy_feature_names.txt", "w") as f:
    for name in feature_names:
        f.write(name + "\n")
print(f"Saved SINDy feature names to {RESULTS_DIR}/sindy_feature_names.txt")

# Save SINDy equations
old_stdout = sys.stdout
sys.stdout = StringIO()
model._model.print()
equations_str = sys.stdout.getvalue()
sys.stdout = old_stdout

with open(f"{RESULTS_DIR}/sindy_equations.txt", "w") as f:
    f.write("Discovered SINDy Equations:\n")
    f.write("=" * 40 + "\n")
    f.write(equations_str)
print(f"Saved SINDy equations to {RESULTS_DIR}/sindy_equations.txt")

# Save configuration as JSON
config = {
    "latent_dim": latent_dim,
    "poly_order": poly_order,
    "num_sensors": num_sensors,
    "lags": lags,
    "train_length": train_length,
    "validate_length": validate_length,
    "dt": dt,
    "threshold": threshold,
    "best_threshold": float(best_threshold),
}
with open(f"{RESULTS_DIR}/config.json", "w") as f:
    json.dump(config, f, indent=2)
print(f"Saved configuration to {RESULTS_DIR}/config.json")

# Compute additional errors for results
# SINDy latent prediction error (training data)
x_sim = model._x_sim
z = model._gru_outs
sindy_latent_error = np.linalg.norm(x_sim - z[: len(x_sim)]) / np.linalg.norm(
    z[: len(x_sim)]
)

# SINDy physical prediction error (test data, use min length to handle shape mismatch)
n_compare = min(len(sindy_physical), len(test_ground_truth))
sindy_physical_error = np.linalg.norm(
    sindy_physical[:n_compare] - test_ground_truth[:n_compare]
) / np.linalg.norm(test_ground_truth[:n_compare])

# Save results as JSON
results = {
    "reconstruction_error": float(relative_error),
    "sindy_latent_error": float(sindy_latent_error),
    "sindy_prediction_error": float(sindy_physical_error),
}
with open(f"{RESULTS_DIR}/results.json", "w") as f:
    json.dump(results, f, indent=2)
print(f"Saved results to {RESULTS_DIR}/results.json")

# Print summary of saved files
print("\n" + "=" * 50)
print("Saved files summary:")
print("=" * 50)
for f in sorted(os.listdir(RESULTS_DIR)):
    fpath = os.path.join(RESULTS_DIR, f)
    size = os.path.getsize(fpath)
    print(f"  {f}: {size/1024:.1f} KB")
# Out:
# Saved latent trajectories to results/synthetic_data/latent_*.npy
# Saved SINDy coefficients to results/synthetic_data/sindy_coefficients.npy
# SINDy coefficients shape: (2, 10)
# Saved SINDy feature names to results/synthetic_data/sindy_feature_names.txt
# Saved SINDy equations to results/synthetic_data/sindy_equations.txt
# Saved configuration to results/synthetic_data/config.json
# Saved results to results/synthetic_data/results.json
#
# ==================================================
# Saved files summary:
# ==================================================
#   config.json: 0.2 KB
#   config.npy: 0.6 KB
#   data_original.npy: 250.1 KB
#   data_original.pdf: 37.5 KB
#   data_original.png: 73.5 KB
#   latent_comparison.pdf: 21.9 KB
#   latent_comparison.png: 185.2 KB
#   latent_sindy_predict.npy: 3.0 KB
#   latent_test.npy: 1.5 KB
#   latent_train.npy: 1.6 KB
#   reconstruction_comparison.pdf: 47.7 KB
#   reconstruction_comparison.png: 97.0 KB
#   results.json: 0.1 KB
#   sensor_predictions_grid.pdf: 35.0 KB
#   shred_model.pt: 589.6 KB
#   sindy_coefficients.npy: 0.3 KB
#   sindy_equations.txt: 0.2 KB
#   sindy_feature_names.txt: 0.0 KB
